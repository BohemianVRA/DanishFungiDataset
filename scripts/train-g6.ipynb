# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %env CUDA_DEVICES = 0
# %env WANDB_ENTITY = zcu_cv
# %env WANDB_PROJECT = DF24
# Out:
# env: CUDA_DEVICES=0
# env: WANDB_ENTITY=zcu_cv
# env: WANDB_PROJECT=DF24

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = os.environ["CUDA_DEVICES"]

# %%
# !nvidia-smi
# Out:
# Tue May 21 00:30:12 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     On  |   00000000:E1:00.0 Off |                    0 |
# |  0%   56C    P0             87W /  300W |   11348MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# !wandb sweep ../sweep/DF24M_384_sweep.yaml

# %%
# !wandb agent zcu_cv/DF24/kudeczv0
# Out:
# wandb: Starting wandb agent 🕵️
# 2024-05-21 00:30:41,965 - wandb.wandb_agent - INFO - Running runs: []
# 2024-05-21 00:30:42,278 - wandb.wandb_agent - INFO - Agent received command: run
# 2024-05-21 00:30:42,278 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	architecture: swin_base_patch4_window7_224.ms_in1k
# 2024-05-21 00:30:42,299 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python danish_fungi_train.py --config-path ../config/DF24_224_config.yaml --wandb-entity zcu_cv --wandb-project DanishFungi2024 --architecture=swin_base_patch4_window7_224.ms_in1k
# 2024-05-21 00:30:47,320 - wandb.wandb_agent - INFO - Running runs: ['k0ol47n0']
# (script) INFO: Loading training config.
# (script) DEBUG: Extra arguments passed to the script: {'architecture': 'swin_base_patch4_window7_224.ms_in1k'}
# (script) DEBUG: Changing config value architecture: vit_base_patch16_224 -> swin_base_patch4_window7_224.ms_in1k
# (script) INFO: Setting run name: swin_base_patch4_window7_224.ms_in1k-SeeSawLoss-vit_heavy
# (script) INFO: Using experiment directory: ../runs/swin_base_patch4_window7_224.ms_in1k-SeeSawLoss-vit_heavy/exp4
# (script) INFO: Using training configuration: {
#     "augmentations": "vit_heavy",
#     "image_size": [
#         224,
#         224
#     ],
#     "dataset": "DF24",
#     "architecture": "swin_base_patch4_window7_224.ms_in1k",
#     "train": null,
#     "loss": "SeeSawLoss",
#     "optimizer": "SGD",
#     "scheduler": "plateau",
#     "epochs": 50,
#     "learning_rate": 0.01,
#     "batch_size": 32,
#     "accumulation_steps": 8,
#     "random_seed": 777,
#     "workers": 12,
#     "multigpu": false,
#     "tags": [
#         "DanishFungi2024",
#         "224x224"
#     ],
#     "root_path": "../",
#     "run_name": "swin_base_patch4_window7_224.ms_in1k-SeeSawLoss-vit_heavy",
#     "exp_name": "exp4",
#     "exp_path": "../runs/swin_base_patch4_window7_224.ms_in1k-SeeSawLoss-vit_heavy/exp4"
# }
# (fgvc) INFO: Using device: cuda (0)
# (fgvc) INFO: Device names: 0: NVIDIA A40
# (script) INFO: Loading training and validation metadata.
# danish_fungi_train.py:38: DtypeWarning: Columns (5,6,17,21,50,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv("../metadata/DanishFungi2024-train-metadata-full-DEV.csv")
# danish_fungi_train.py:44: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv("../metadata/DanishFungi2024-test-metadata-full-DEV.csv")
# (script) INFO: Creating model, optimizer, and scheduler.
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3423.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# (fgvc) DEBUG: Setting new prediction head with random initial weights.
# (script) INFO: Creating DataLoaders.
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# (script) INFO: Creating loss function.
# torch.float32
# wandb: Currently logged in as: picekl (zcu_cv). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: wandb version 0.17.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.11
# wandb: Run data is saved locally in /auto/plzen4-ntis/home/picekl/Projects/DanishFungiDataset/scripts/wandb/run-20240521_003122-k0ol47n0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swin_base_patch4_window7_224.ms_in1k-SeeSawLoss-vit_heavy
# wandb: ⭐️ View project at https://wandb.ai/zcu_cv/DF24
# wandb: 🧹 View sweep at https://wandb.ai/zcu_cv/DF24/sweeps/kudeczv0
# wandb: 🚀 View run at https://wandb.ai/zcu_cv/DF24/runs/k0ol47n0
# (script) INFO: Training the model.
# 2024-05-21 00:31:23,760 - fgvc-training - INFO - Training started.
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:14<00:00,  4.05it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [10:22<00:00,  4.56it/s]
# 2024-05-21 01:38:20,914 - fgvc-training - INFO - Epoch 1 - avg_train_loss: 3.5738	avg_val_loss: 2.0741	F1: 19.02%	Accuracy: 52.70%	Recall@3: 68.82%	time: 4017s
# 2024-05-21 01:38:20,919 - fgvc-training - INFO - Epoch 1 - Save checkpoint with best validation loss: 2.074147
# 2024-05-21 01:38:22,156 - fgvc-training - INFO - Epoch 1 - Save checkpoint with best validation accuracy: 0.527011
# 2024-05-21 01:38:23,472 - fgvc-training - INFO - Epoch 1 - Save checkpoint with best validation recall@3: 0.688210
# 2024-05-21 01:38:24,608 - fgvc-training - INFO - Epoch 1 - Save checkpoint with best validation f1: 0.190169
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [55:14<00:00,  4.12it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [09:35<00:00,  4.93it/s]
# 2024-05-21 02:43:42,579 - fgvc-training - INFO - Epoch 2 - avg_train_loss: 1.8782	avg_val_loss: 1.6262	F1: 26.78%	Accuracy: 59.95%	Recall@3: 75.54%	time: 3914s
# 2024-05-21 02:43:42,584 - fgvc-training - INFO - Epoch 2 - Save checkpoint with best validation loss: 1.626175
# 2024-05-21 02:43:43,761 - fgvc-training - INFO - Epoch 2 - Save checkpoint with best validation accuracy: 0.599471
# 2024-05-21 02:43:44,897 - fgvc-training - INFO - Epoch 2 - Save checkpoint with best validation recall@3: 0.755394
# 2024-05-21 02:43:46,108 - fgvc-training - INFO - Epoch 2 - Save checkpoint with best validation f1: 0.267790
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [55:24<00:00,  4.11it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [08:43<00:00,  5.42it/s]
# 2024-05-21 03:48:20,496 - fgvc-training - INFO - Epoch 3 - avg_train_loss: 1.4940	avg_val_loss: 1.4285	F1: 31.16%	Accuracy: 63.03%	Recall@3: 78.29%	time: 3871s
# 2024-05-21 03:48:20,501 - fgvc-training - INFO - Epoch 3 - Save checkpoint with best validation loss: 1.428477
# 2024-05-21 03:48:21,733 - fgvc-training - INFO - Epoch 3 - Save checkpoint with best validation accuracy: 0.630343
# 2024-05-21 03:48:22,866 - fgvc-training - INFO - Epoch 3 - Save checkpoint with best validation recall@3: 0.782940
# 2024-05-21 03:48:24,018 - fgvc-training - INFO - Epoch 3 - Save checkpoint with best validation f1: 0.311605
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [55:23<00:00,  4.11it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:51<00:00,  4.00it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [07:54<00:00,  5.98it/s]
# 2024-05-21 15:47:37,054 - fgvc-training - INFO - Epoch 14 - avg_train_loss: 0.4840	avg_val_loss: 1.2216	F1: 38.44%	Accuracy: 69.68%	Recall@3: 83.44%	time: 3908s
# 2024-05-21 15:47:37,059 - fgvc-training - INFO - Epoch 14 - Save checkpoint with best validation accuracy: 0.696845
# 2024-05-21 15:47:38,291 - fgvc-training - INFO - Epoch 14 - Save checkpoint with best validation recall@3: 0.834396
# 2024-05-21 15:47:39,437 - fgvc-training - INFO - Epoch 14 - Save checkpoint with best validation f1: 0.384441
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:43<00:00,  4.01it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [08:21<00:00,  5.66it/s]
# Epoch 00015: reducing learning rate of group 0 to 7.2900e-03.
# 2024-05-21 16:53:11,111 - fgvc-training - INFO - Epoch 15 - avg_train_loss: 0.4548	avg_val_loss: 1.2440	F1: 38.30%	Accuracy: 68.99%	Recall@3: 83.16%	time: 3928s
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:02<00:00,  4.06it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:26<00:00,  4.03it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [08:06<00:00,  5.84it/s]
# Epoch 00017: reducing learning rate of group 0 to 6.5610e-03.
# 2024-05-21 19:03:08,567 - fgvc-training - INFO - Epoch 17 - avg_train_loss: 0.3743	avg_val_loss: 1.2509	F1: 38.48%	Accuracy: 69.27%	Recall@3: 83.21%	time: 3896s
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:46<00:00,  4.01it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [08:32<00:00,  5.54it/s]
# 2024-05-21 20:08:51,028 - fgvc-training - INFO - Epoch 18 - avg_train_loss: 0.3360	avg_val_loss: 1.2456	F1: 39.00%	Accuracy: 69.92%	Recall@3: 83.59%	time: 3940s
# 2024-05-21 20:08:51,034 - fgvc-training - INFO - Epoch 18 - Save checkpoint with best validation accuracy: 0.699201
# 2024-05-21 20:08:52,206 - fgvc-training - INFO - Epoch 18 - Save checkpoint with best validation recall@3: 0.835894
# 2024-05-21 20:08:53,419 - fgvc-training - INFO - Epoch 18 - Save checkpoint with best validation f1: 0.390027
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:37<00:00,  4.02it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [07:51<00:00,  6.02it/s]
# Epoch 00019: reducing learning rate of group 0 to 5.9049e-03.
# 2024-05-21 21:13:49,457 - fgvc-training - INFO - Epoch 19 - avg_train_loss: 0.3094	avg_val_loss: 1.2633	F1: 38.85%	Accuracy: 69.81%	Recall@3: 83.44%	time: 3892s
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:33<00:00,  4.02it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [08:28<00:00,  5.58it/s]
# 2024-05-21 22:19:22,443 - fgvc-training - INFO - Epoch 20 - avg_train_loss: 0.2813	avg_val_loss: 1.2582	F1: 39.12%	Accuracy: 70.21%	Recall@3: 83.61%	time: 3925s
# 2024-05-21 22:19:22,448 - fgvc-training - INFO - Epoch 20 - Save checkpoint with best validation accuracy: 0.702120
# 2024-05-21 22:19:24,487 - fgvc-training - INFO - Epoch 20 - Save checkpoint with best validation recall@3: 0.836147
# 2024-05-21 22:19:26,243 - fgvc-training - INFO - Epoch 20 - Save checkpoint with best validation f1: 0.391160
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [56:01<00:00,  4.06it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [55:11<00:00,  4.12it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 2838/2838 [05:26<00:00,  8.68it/s]
# 2024-05-22 23:32:44,110 - fgvc-training - INFO - Epoch 44 - avg_train_loss: 0.1013	avg_val_loss: 1.3283	F1: 40.05%	Accuracy: 71.32%	Recall@3: 84.25%	time: 3658s
# 2024-05-22 23:32:44,115 - fgvc-training - INFO - Epoch 44 - Save checkpoint with best validation recall@3: 0.842546
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████| 13650/13650 [55:30<00:00,  4.10it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#  31%|████████████▏                           | 866/2838 [01:54<03:24,  9.66it/s]

# %%
# !python danish_fungi_train.py \
    --config-path ../config/DF24M_224_config.yaml \
    --cuda-devices $CUDA_DEVICES \
    --wandb-entity $WANDB_ENTITY \
    --wandb-project $WANDB_PROJECT

# %%
# !python danish_fungi_train.py \
    --config-path ../config/DF24M_224_config.yaml \
    --cuda-devices $CUDA_DEVICES \
    --wandb-entity $WANDB_ENTITY \
    --wandb-project $WANDB_PROJECT
# Out:
# 100%|███████████████████████████████████████| 1472/1472 [02:20<00:00, 10.49it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████| 298/298 [00:17<00:00, 16.69it/s]
# 2024-05-15 00:40:51,956 - fgvc-training - INFO - Epoch 47 - avg_train_loss: 0.3200	avg_val_loss: 1.4298	F1: 35.85%	Accuracy: 63.55%	Recall@3: 81.22%	time: 161s
# 2024-05-15 00:40:51,961 - fgvc-training - INFO - Epoch 47 - Save checkpoint with best validation recall@3: 0.812198
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 1472/1472 [02:20<00:00, 10.48it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████| 298/298 [00:17<00:00, 16.90it/s]
# Epoch 00048: reducing learning rate of group 0 to 1.5009e-02.
# 2024-05-15 00:43:34,037 - fgvc-training - INFO - Epoch 48 - avg_train_loss: 0.3131	avg_val_loss: 1.4252	F1: 35.61%	Accuracy: 63.13%	Recall@3: 81.22%	time: 161s
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 1472/1472 [02:19<00:00, 10.52it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████| 298/298 [00:17<00:00, 16.73it/s]
# 2024-05-15 00:46:15,462 - fgvc-training - INFO - Epoch 49 - avg_train_loss: 0.3085	avg_val_loss: 1.4350	F1: 35.89%	Accuracy: 63.48%	Recall@3: 81.25%	time: 161s
# 2024-05-15 00:46:15,468 - fgvc-training - INFO - Epoch 49 - Save checkpoint with best validation recall@3: 0.812513
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|███████████████████████████████████████| 1472/1472 [02:20<00:00, 10.48it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100%|█████████████████████████████████████████| 298/298 [00:18<00:00, 16.38it/s]
# Epoch 00050: reducing learning rate of group 0 to 1.3509e-02.
# 2024-05-15 00:48:58,268 - fgvc-training - INFO - Epoch 50 - avg_train_loss: 0.3027	avg_val_loss: 1.4390	F1: 35.65%	Accuracy: 62.99%	Recall@3: 81.23%	time: 161s
# 2024-05-15 00:48:59,127 - fgvc-training - INFO - Save checkpoint of the last epoch
# 2024-05-15 00:48:59,583 - fgvc-training - INFO - Best scores (validation loss): avg_train_loss: 0.9472	avg_val_loss: 1.2768	F1: 33.51%	Accuracy: 60.96%	Recall@3: 79.71%	time: 161s
# 2024-05-15 00:48:59,583 - fgvc-training - INFO - Best scores (validation Accuracy): avg_train_loss: 0.3190	avg_val_loss: 1.4437	F1: 36.50%	Accuracy: 63.56%	Recall@3: 80.87%	time: 162s
# 2024-05-15 00:48:59,584 - fgvc-training - INFO - Best scores (validation Recall@3): avg_train_loss: 0.3085	avg_val_loss: 1.4350	F1: 35.89%	Accuracy: 63.48%	Recall@3: 81.25%	time: 161s
# 2024-05-15 00:48:59,584 - fgvc-training - INFO - Best scores (validation F1): avg_train_loss: 0.3190	avg_val_loss: 1.4437	F1: 36.50%	Accuracy: 63.56%	Recall@3: 80.87%	time: 162s
# 2024-05-15 00:48:59,584 - fgvc-training - INFO - Training done in 8188.985267400742s.
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:556: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# (script) INFO: Creating predictions.
# 100%|█████████████████████████████████████████| 333/333 [00:20<00:00, 16.08it/s]
# {'Accuracy': 0.6114661654135338, 'Recall@3': 0.7926691729323309, 'F1': 0.33173149226652604}
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:     Learning Rate ██████████▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁
# wandb: Max Gradient Norm ▃█▅▇▇▆▅▆▅▅▄▄▅▅▅▅▄▅▄▄▄▄▅▂▂▄▃▃▄▂▃▃▃▃▁▄▂▃▃▂
# wandb:     test/Accuracy ▁
# wandb:           test/F1 ▁
# wandb:     test/Recall@3 ▁
# wandb:    train/Accuracy ▁▃▃▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇████████████████
# wandb:          train/F1 ▁▂▂▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████
# wandb: train/Loss (avr.) █▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      val/Accuracy ▁▄▅▅▆▇▇▇▇▇▇▇▇▇█▇████████████████████████
# wandb:            val/F1 ▁▃▄▅▆▆▆▇▇▇▇▇▇▇████▇█████████████████████
# wandb:   val/Loss (avr.) █▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:      val/Recall@3 ▁▄▅▆▇▇▇▇▇▇▇█████████████████████████████
# wandb:
# wandb: Run summary:
# wandb:     Learning Rate 0.01501
# wandb: Max Gradient Norm 1.10522
# wandb:     test/Accuracy 0.61147
# wandb:           test/F1 0.33173
# wandb:     test/Recall@3 0.79267
# wandb:    train/Accuracy 0.89091
# wandb:          train/F1 0.85253
# wandb: train/Loss (avr.) 0.30274
# wandb:      val/Accuracy 0.62986
# wandb:            val/F1 0.35654
# wandb:   val/Loss (avr.) 1.43898
# wandb:      val/Recall@3 0.8123
# wandb:
# wandb: 🚀 View run resnet50.a1_in1k-SeeSawLoss-vit_heavy at: https://wandb.ai/zcu_cv/DF24/runs/rpdli3bk
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240514_223229-rpdli3bk/logs
# (script) INFO: Setting the best scores in the W&B run summary.
# ../runs/resnet50.a1_in1k-SeeSawLoss-vit_heavy/exp8/best_f1.pth
# Upload 1 LFS files:   0%|                                 | 0/1 [00:00<?, ?it/s]
# best_f1.bin:   0%|                                  | 0.00/96.2M [00:00<?, ?B/s]
# best_f1.bin:   0%|                         | 8.19k/96.2M [00:00<20:44, 77.3kB/s]
# best_f1.bin:   1%|▏                         | 786k/96.2M [00:00<00:23, 4.04MB/s]
# best_f1.bin:   5%|█▏                       | 4.37M/96.2M [00:00<00:07, 11.7MB/s]
# best_f1.bin:   9%|██▎                      | 9.06M/96.2M [00:00<00:04, 18.9MB/s]
# best_f1.bin:  12%|██▉                      | 11.2M/96.2M [00:00<00:05, 15.1MB/s]
# best_f1.bin:  15%|███▋                     | 14.2M/96.2M [00:00<00:04, 17.5MB/s]
# best_f1.bin:  17%|████▏                    | 16.0M/96.2M [00:01<00:08, 9.41MB/s]
# best_f1.bin:  18%|████▌                    | 17.4M/96.2M [00:01<00:08, 9.53MB/s]
# best_f1.bin:  21%|█████▎                   | 20.4M/96.2M [00:01<00:06, 11.6MB/s]
# best_f1.bin:  26%|██████▌                  | 25.1M/96.2M [00:01<00:04, 16.8MB/s]
# best_f1.bin:  28%|███████                  | 27.2M/96.2M [00:02<00:05, 13.6MB/s]
# best_f1.bin:  32%|███████▉                 | 30.6M/96.2M [00:02<00:03, 16.5MB/s]
# best_f1.bin:  34%|████████▍                | 32.7M/96.2M [00:02<00:07, 8.64MB/s]
# best_f1.bin:  39%|█████████▊               | 37.8M/96.2M [00:02<00:04, 13.3MB/s]
# best_f1.bin:  42%|██████████▍              | 40.0M/96.2M [00:03<00:04, 14.0MB/s]
# best_f1.bin:  44%|██████████▉              | 42.0M/96.2M [00:03<00:03, 14.2MB/s]
# best_f1.bin:  47%|███████████▊             | 45.6M/96.2M [00:03<00:02, 18.0MB/s]
# best_f1.bin:  50%|████████████▍            | 48.0M/96.2M [00:03<00:04, 10.1MB/s]
# best_f1.bin:  52%|████████████▉            | 49.8M/96.2M [00:04<00:04, 9.50MB/s]
# best_f1.bin:  53%|█████████████▎           | 51.3M/96.2M [00:04<00:04, 10.0MB/s]
# best_f1.bin:  56%|██████████████           | 54.1M/96.2M [00:04<00:03, 13.0MB/s]
# best_f1.bin:  61%|███████████████▏         | 58.5M/96.2M [00:04<00:02, 18.5MB/s]
# best_f1.bin:  63%|███████████████▊         | 61.0M/96.2M [00:04<00:02, 14.7MB/s]
# best_f1.bin:  67%|████████████████▋        | 64.0M/96.2M [00:05<00:03, 9.61MB/s]
# best_f1.bin:  68%|█████████████████        | 65.6M/96.2M [00:05<00:03, 9.78MB/s]
# best_f1.bin:  74%|██████████████████▍      | 71.0M/96.2M [00:05<00:01, 15.1MB/s]
# best_f1.bin:  76%|███████████████████      | 73.1M/96.2M [00:05<00:01, 14.2MB/s]
# best_f1.bin:  82%|████████████████████▍    | 78.7M/96.2M [00:05<00:00, 20.9MB/s]
# best_f1.bin:  85%|█████████████████████▏   | 81.5M/96.2M [00:06<00:01, 11.9MB/s]
# best_f1.bin:  91%|██████████████████████▋  | 87.3M/96.2M [00:06<00:00, 17.6MB/s]
# best_f1.bin:  94%|███████████████████████▌ | 90.4M/96.2M [00:06<00:00, 15.6MB/s]
# best_f1.bin: 100%|█████████████████████████| 96.2M/96.2M [00:08<00:00, 11.6MB/s]
# Upload 1 LFS files: 100%|█████████████████████████| 1/1 [00:08<00:00,  8.34s/it]

# %%
# !python danish_fungi_train.py \
    --config-path ../config/DF24M_384_tf_efficientnet_b3.ap_in1k.yaml \
    --cuda-devices $CUDA_DEVICES \
    --wandb-entity $WANDB_ENTITY \
    --wandb-project $WANDB_PROJECT
