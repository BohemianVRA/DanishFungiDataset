# %%
# %env CUDA_DEVICES = 0
# %env WANDB_ENTITY = zcu_cv
# %env WANDB_PROJECT = DanishFungi2023
# Out:
# env: CUDA_DEVICES=0
# env: WANDB_ENTITY=zcu_cv
# env: WANDB_PROJECT=DanishFungi2023

# %%
# !nvidia-smi
# Out:
# Mon Sep 11 09:44:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A40          On   | 00000000:61:00.0 Off |                    0 |
# |  0%   44C    P0    77W / 300W |   2918MiB / 46068MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A40          On   | 00000000:E1:00.0 Off |                    0 |
# |  0%   34C    P8    11W / 300W |      0MiB / 46068MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    279416      C   /usr/bin/python                  2916MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = os.environ["CUDA_DEVICES"]

# %%
# !python danishfungi2023_train.py \
    --config-path configs/vit_large_patch16_224.augreg_in21k_ft_in1k.yaml \
    --cuda-devices $CUDA_DEVICES \
    --wandb-entity $WANDB_ENTITY \
    --wandb-project $WANDB_PROJECT
# Out:
# (script) INFO: Loading training config.
# (script) DEBUG: Extra arguments passed to the script: {}
# (script) INFO: Setting run name: vit_large_patch16_224.augreg_in21k_ft_in1k-CrossEntropyLoss-light
# (script) INFO: Using experiment directory: ./runs/vit_large_patch16_224.augreg_in21k_ft_in1k-CrossEntropyLoss-light/exp1
# (script) INFO: Using training configuration: {
#     "augmentations": "light",
#     "image_size": [
#         224,
#         224
#     ],
#     "dataset": "DanishFungi2023-v0.1",
#     "architecture": "vit_large_patch16_224.augreg_in21k_ft_in1k",
#     "loss": "CrossEntropyLoss",
#     "optimizer": "SGD",
#     "scheduler": "cosine",
#     "epochs": 100,
#     "learning_rate": 0.01,
#     "batch_size": 64,
#     "accumulation_steps": 4,
#     "random_seed": 777,
#     "workers": 12,
#     "multigpu": false,
#     "tags": [
#         "Fine-tuning",
#         "Dino",
#         "DanishFungi2023"
#     ],
#     "root_path": "./",
#     "run_name": "vit_large_patch16_224.augreg_in21k_ft_in1k-CrossEntropyLoss-light",
#     "exp_name": "exp1",
#     "exp_path": "./runs/vit_large_patch16_224.augreg_in21k_ft_in1k-CrossEntropyLoss-light/exp1"
# }
# (fgvc) INFO: Using device: cuda (0)
# (fgvc) INFO: Device names: 0: NVIDIA A40
# (script) INFO: Loading training and validation metadata.
# (script) INFO: Creating model, optimizer, and scheduler.
# Downloading model.safetensors: 100%|███████| 1.22G/1.22G [00:38<00:00, 31.4MB/s]
# (fgvc) DEBUG: Setting new prediction head with random initial weights.
# (script) INFO: Creating DataLoaders.
# (script) INFO: Creating loss function.
# wandb: Currently logged in as: picekl (zcu_cv). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.11
# wandb: Run data is saved locally in /auto/plzen4-ntis/home/picekl/Projects/DanishFungiDataset/wandb/run-20230911_094713-eifvyu0a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit_large_patch16_224.augreg_in21k_ft_in1k-CrossEntropyLoss-light
# wandb: ⭐️ View project at https://wandb.ai/zcu_cv/DanishFungi2023
# wandb: 🚀 View run at https://wandb.ai/zcu_cv/DanishFungi2023/runs/eifvyu0a
# (script) INFO: Training the model.
# 2023-09-11 09:47:15,294 - fgvc-training - INFO - Training started.
#  17%|██████▊                                 | 710/4162 [09:20<45:03,  1.28it/s]/storage/plzen4-ntis/home/picekl/.local-carnivore_id_v22_12_0.sif/lib/python3.8/site-packages/PIL/Image.py:3011: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#  17%|██████▉                                 | 722/4162 [09:30<45:03,  1.27it/s]/storage/plzen4-ntis/home/picekl/.local-carnivore_id_v22_12_0.sif/lib/python3.8/site-packages/PIL/Image.py:3011: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#